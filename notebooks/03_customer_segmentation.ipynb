# %% [markdown]
# # 03 — Customer Segmentation (RFM)
#
# **Project:** Enterprise Marketing Analytics & Customer 360 Platform
# **Status:** PLACEHOLDER — run after EDA notebook
#
# ## Objectives
# 1. Calculate Recency, Frequency, Monetary per customer
# 2. Assign RFM scores and segment labels
# 3. Profile segments (size, revenue, avg CLV)
# 4. Validate against `sql/05_customer_segmentation.sql`
#
# ## Segments (target)
# - Champions
# - Loyal Customers
# - Potential Loyalists
# - At Risk
# - Lost
#
# ## Sections
# - [ ] Load customer order history
# - [ ] Compute RFM metrics
# - [ ] Quintile scoring
# - [ ] Segment assignment
# - [ ] Segment profiles
# - [ ] Visualizations for Power BI Page 2

# %%
# PLACEHOLDER: RFM setup
from pathlib import Path
import pandas as pd

PROCESSED_DIR = Path('../data/processed')
