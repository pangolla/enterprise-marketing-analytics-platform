# %% [markdown]
# # 01 — Data Cleaning
#
# **Project:** Enterprise Marketing Analytics & Customer 360 Platform
# **Dataset:** Olist Brazilian E-Commerce
# **Status:** Complete — raw CSVs in `data/raw/`, cleaned outputs in `data/processed/`
#
# ## Objectives
# 1. Load raw Olist CSVs
# 2. Inspect schema, nulls, and data types
# 3. Clean timestamps, categories, and prices
# 4. Export cleaned tables to `data/processed/`
#
# ## Sections
# - [x] Setup and paths
# - [x] Run cleaning pipeline (`src/data_cleaning.py`)
# - [x] Data quality summary
# - [x] Export processed files

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from data_cleaning import run_cleaning_pipeline

tables = run_cleaning_pipeline()
quality = tables['data_quality_report']
quality
# Out:
# Loading raw Olist files from data/raw/ ...
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/orders.csv (99,441 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/order_items.csv (112,650 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/products.csv (32,951 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/customers.csv (99,441 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/reviews.csv (99,224 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/payments.csv (103,886 rows)
# Exported: /Users/angollapraveengoud/Desktop/enterprise-marketing-analytics-platform/data/processed/data_quality_report.csv (11 rows)
#
# Data quality summary:
# ...

# %%
import pandas as pd

processed = Path('../data/processed')
for name in ['orders', 'order_items', 'products', 'customers', 'reviews']:
    df = pd.read_csv(processed / f'{name}.csv', nrows=3)
    print(f'\n=== {name} ({len(pd.read_csv(processed / f"{name}.csv")):,} rows) ===')
    display(df.head(2))
# Out:
# === orders (99,441 rows) ===
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
#
#   order_estimated_delivery_date  is_delivered  delivery_delay_days  \
# 0                    2017-10-18             1                 -8.0
# 1                    2018-08-13             1                 -6.0
#
#    is_delayed purchase_date
# 0           0    2017-10-02
# 1           0    2018-07-24
# === order_items (112,650 rows) ===
# ...
